# %% [raw]
# ---
# title: 'About Me'
# author: Hannah Kim
# sidebar: false
# format:
#   html:
#     embed-resources: false
#     code-fold: true
# execute:
#   echo: false
#   warning: false
# jupyter: python3
# ---

# %% [markdown]
# ## Hannah Kim
# __an Aspiring Data Scientist and Analyst · hk932@georgetown.edu__
#
# ::::{.columns}
# :::{.column width="47.5%"}
# ![Hannah Kim](./images/Hannah_Kim_profile.jpg)
# :::
#
# :::{.column width="5%"}
# <!--make space-->
# :::
#
# :::{.column width="47.5%"}
# Hello! I am Hannah Kim, a graduate student at Georgetown University majoring in Masters of Science of Data Science and Analytics. I completed my undergraduate studies in Software Engineering with experiences in Java and C, and now pursuing to become a data scientist, analyst who can convey meaningful results to the audience. After graduating my undergrad, I worked at Medtronic Korea as a Technical User Support Analyst and not only did I gain technical skills in hardware field, but I also improved communication skills by meeting new people. After working for a year, I successfully made it to the United States in 2023! I am soon graduating from my master’s degree and I am looking for an exciting and professional challenge and am keen to continue my career. Outside of school, I love to go out and enjoy playing with my cats. I have two cats in my hometown: Pepper, Button, and kept Cabbage for approximately two months. Checkout my cats and see how cute they are!
# :::
# ::::
# <br>
# <br>
# <br>
#
# ## My Cats
#
# ::::{.columns}
# :::{.column width="32%"}
# ![Pepper](images/pepper.png)
# :::
#
# :::{.column width="2%"}
# <!--make space-->
# :::
# :::{.column width="32%"}
# ![Button](images/button.png)
# :::
# :::{.column width="2%"}
# <!--make space-->
# :::
# :::{.column width="32%"}
# ![Cabbage](images/cabbage.png)
# :::
# ::::
# <br><br>
#
# :::: {.columns}
# ::: {.column width="32%"}
# {{< video images/pepper_3.mp4 width="300" height="400" >}}
# :::
#
# ::: {.column width="2%"}
# <!--make_space-->
# :::
#
# ::: {.column width="32%"}
# {{< video images/button_4.mp4 width="300" height="400" >}}
# :::
#
# ::: {.column width="2%"}
# <!--make_space-->
# :::
#
# ::: {.column width="32%"}
# {{< video images/cabbage_3.mp4 width="300" height="400" >}}
# :::
# ::::
#
# ## Work Experience
#
# __Research Scholar__ | Jan 2025 - Present |
#
# _Massive Data Institute_ | Washington DC, USA
#
# __Associate Technical User Support Analyst__ / Full-time | Mar, 2022 - Mar, 2023
#
# _Medtronic Korea_ | Seoul, South Korea
#
# __Data Mining Research Assistant__ | Sep, 2018 - Dec, 2018
#
# _Gachon University / Big Data Lab_ | Gyeonggi, South Korea
#
# __Java Engineer__ | May, 2018 - Aug, 2018
#
# _HealthMax_ | Seoul, South Korea
#
# ## Education
# __Georgetown University__ | Washington DC, USA
#
# _Masters in Science in Data Science and Analytics_ | June, 2023 - May, 2025
# <br>
#
# __Gachon University__ | Gyeonggi, South Korea
#
# _Bachelor of Engineering, Majored in Software_ | Dean's List (Fall, 2017) | Mar, 2016 - Feb, 2021
